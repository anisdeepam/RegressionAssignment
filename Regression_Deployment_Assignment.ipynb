# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('insurance_pre.csv')
df = pd.get_dummies(df, drop_first=True)
independent =  df[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = df[["charges"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.3, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
scy = StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)

# %%
preinput = sc.transform([[19, 27, 0, 0, 1]])
preinput
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.46169465, -0.60208803, -0.89833872, -0.97676557,  1.98149332]])

# %%
import pickle
loaded_model = pickle.load(open('final_regression_model.pkl','rb'))
result = loaded_model.predict(preinput)
result
# Out:
# array([0.31723763])

# %%
preoutput = scy.inverse_transform([result])
preoutput
# Out:
# array([[16999.7207052]])
